# %%
import sys, os
sys.path.append("..")

# %%
from src.train import train_and_evaluate

# %%
# !ls
# Out:
# clinvar_outs_model1  train_model1.ipynb  train_model3.ipynb
# clinvar_outs_model2  train_model2.ipynb

# %%
from src.config_utils import load_config

# %%
config_path = "../config/clinvar_nt-mean.yaml"

# %%
cfg = load_config(config_path)

# %%
cfg
# Out:
# {'paths': {'data_root': '../../clinvar_data',
#   'ref_dir': '../../clinvar_data/refs/GRCh38_gencode',
#   'clinvar_vcf': '../../clinvar_data/clinvar_GRCh38.vcf.gz',
#   'fasta': '../../clinvar_data/refs/GRCh38_gencode/GRCh38.primary_assembly.genome.fa',
#   'processed_dir': '../../clinvar_data/processed_data',
#   'output_dir': './clinvar_outs_model2',
#   'paired_csv': '../../clinvar_data/processed_data/clinvar_paired_gencode.csv'},
#  'data': {'seq_len': 1004,
#   'kmer': 6,
#   'max_tokens': 256,
#   'pos_label': 'pathogenic',
#   'neg_label': 'benign',
#   'chrom_split': True,
#   'val_chroms': ['8'],
#   'test_chroms': ['18', '21'],
#   'subset_per_class': 40000},
#  'model': {'name': 'InstaDeepAI/nucleotide-transformer-500m-human-ref',
#   'embed_method': 'mean',
#   'run_name': None},
#  'training': {'seed': 42,
#   'batch_size': 16,
#   'num_epochs': 5,
#   'lr': '5e-4',
#   'num_workers': 4,
#   'metric_for_best': 'auroc',
#   'logging_steps': 100},
# ...

# %%
metrics_cls = train_and_evaluate(config_path)
# Out:
# Loading existing paired CSV from ../../clinvar_data/processed_data/clinvar_paired_gencode.csv
# /scratch/ml-csm/users/nishan/nkfiles/Notebooks/GenAI_project/nt-clinvar-ft/notebooks/../src/data.py:231: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(paired_csv)
# Subsampling to 40000 per class
# label
# benign        40000
# pathogenic    40000
# Name: count, dtype: int64
# /scratch/ml-csm/users/nishan/nkfiles/Notebooks/GenAI_project/nt-clinvar-ft/notebooks/../src/data.py:271: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(
# ...
